# %% [markdown]
# # Jahresabschluss
# ## EEG - Erneuerbare Energie Gemeinschaft
#
# Dieses Notebook dient zur Generierung des Jahresabschlusses aus der Django-Datenbank.
#
# ### Aktuelle Jahresabschlüsse:
# - [2025](/notebooks/finance/Jahresabschluss/2025/2025-01-01_2025-12-31.xlsx) - Automatisch generiert aus der Datenbank
# - [2023](/notebooks/finance/Jahresabschluss/2023/2023-01-01_2023-12-31.xlsx) - Historisch
#
# ### Anleitung:
# 1. Führe das Skript `generate_2025.py` aus, um den Jahresabschluss zu generieren
# 2. Oder öffne das Notebook `Abschluss_2025.ipynb` für eine interaktive Analyse

# %%
# Aktuelles Jahr setzen
YEAR = 2025
print(f'Jahresabschluss für {YEAR} wird generiert')

# %%
# Führe das Generierungsskript aus
# %run generate_2025.py

# %% [markdown]
# ## Ergebnisse
#
# Der Jahresabschluss wurde generiert. Siehe:
# - Excel-Datei: `/notebooks/finance/Jahresabschluss/2025/2025-01-01_2025-12-31.xlsx`
# - Zusammenfassung: 69 Buchungen, Saldo: -2.019,35 EUR
