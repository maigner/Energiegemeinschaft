# %%
import pandas as pd

members_df = pd.read_excel("EEGFakturaExports/RC101533-EEG-Masterdata-20240122.xlsx", sheet_name="Mitglieder")
members_df

from dotenv import load_dotenv
import os 

load_dotenv()
#p = os.getenv('MIDDLEWARE_DB_PASSWORD')

members_df
# Out:
#    Mit. Nr.    Name 1   Name 2 Titel  Status Mitglied seit.  \
# 0         1    Martin   Aigner   NaN  ACTIVE     2024-01-10
# 1         1    Martin   Aigner   NaN  ACTIVE     2024-01-10
# 2         3  Johannes     Kals   NaN  ACTIVE     2024-01-21
# 3         3  Johannes     Kals   NaN  ACTIVE     2024-01-21
# 4         2    Martin   Schott   NaN  ACTIVE     2024-01-21
# 5         2    Martin   Schott   NaN  ACTIVE     2024-01-21
# 6         4   Herward  Zitterl   Dr.  ACTIVE     2024-01-21
# 7         4   Herward  Zitterl   Dr.  ACTIVE     2024-01-21
#
#                       E-Mail  Telefonnummer  SteuerNr.  Ust.  ...  \
# 0         martin@maigner.net            NaN        NaN   NaN  ...
# 1         martin@maigner.net            NaN        NaN   NaN  ...
# 2    johanneskals@icloud.com            NaN        NaN   NaN  ...
# 3    johanneskals@icloud.com            NaN        NaN   NaN  ...
# 4     schottm4rtin@gmail.com            NaN        NaN   NaN  ...
# 5     schottm4rtin@gmail.com            NaN        NaN   NaN  ...
# 6  herward.zitterl@gmail.com            NaN        NaN   NaN  ...
# 7  herward.zitterl@gmail.com            NaN        NaN   NaN  ...
#
#   Bezugsrichtung WechselrichterNr.  PLZ.1      Ort.1          Straße.1  \
# 0    CONSUMPTION               NaN   4820  Bad Ischl        Loskoglweg
# 1     GENERATION               NaN   4820  Bad Ischl        Loskoglweg
# 2    CONSUMPTION               NaN   4820  Bad Ischl  Rittingerstrasse
# 3    CONSUMPTION               NaN   4820  Bad Ischl  Rittingerstrasse
# 4    CONSUMPTION               NaN   4820  Bad Ischl  Sarsteinerstraße
# 5     GENERATION               NaN   4820  Bad Ischl  Sarsteinerstraße
# 6    CONSUMPTION               NaN   4820  Bad Ischl       Frauengasse
# 7     GENERATION               NaN   4820  Bad Ischl       Frauengasse
#
#   HausNr..1               aktiviert          deaktiviert   Zp. Tarifname  \
# 0        14 2024-01-01 00:00:00.000  2999-12-31 00:00:00  Verbrauch-2024
# 1        14 2024-01-11 11:41:36.377  2999-12-31 00:00:00  Erzeugung-2024
# 2         1 2024-01-21 20:57:10.367  2999-12-31 00:00:00  Verbrauch-2024
# 3         1 2024-01-21 20:58:50.004  2999-12-31 00:00:00  Verbrauch-2024
# 4         8 2024-01-21 20:56:50.192  2999-12-31 00:00:00  Verbrauch-2024
# 5         8 2024-01-21 20:53:32.507  2999-12-31 00:00:00  Erzeugung-2024
# 6         8 2024-01-21 21:03:10.050  2999-12-31 00:00:00  Verbrauch-2024
# 7         8 2024-01-21 21:06:19.506  2999-12-31 00:00:00  Erzeugung-2024
#
#   Umspannwerk
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
#
# [8 rows x 37 columns]

# %%
email_list = members_df['E-Mail'].unique()
email_list
# Out:
# array(['martin@maigner.net', 'johanneskals@icloud.com',
#        'schottm4rtin@gmail.com', 'herward.zitterl@gmail.com'],
#       dtype=object)
